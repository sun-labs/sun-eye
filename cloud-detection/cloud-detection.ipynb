# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import Image

# %%
img = cv2.imread('night-sky.jpg')
hsv=cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
white = np.array([255, 255, 255])
lowerBound = np.array([25,25,25])
mask = cv2.inRange(hsv, lowerBound, white)
res = cv2.bitwise_and(img, img, mask=mask)

# %%
plt.imshow(img)
plt.show()

# %%
plt.imshow(res)
plt.show()

# %%
ret,thresh_img = cv2.threshold(res,0,255,cv2.THRESH_BINARY)

# %%
plt.imshow(thresh_img)
plt.show()

# %%
img = cv2.imread('sunny-sky.jpg')
hsv=cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
white = np.array([255, 255, 255])
lowerBound = np.array([25,25,25])
mask = cv2.inRange(hsv, lowerBound, white)
res = cv2.bitwise_and(img, img, mask=mask)

# %%
plt.imshow(img)
plt.show()

# %%
plt.imshow(res)
plt.show()

# %%
ret,thresh_img = cv2.threshold(res,0,255,cv2.THRESH_BINARY)

# %%
plt.imshow(thresh_img)
plt.show()

# %%
img = cv2.imread('cloud-sky.jpg')
hsv=cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
white = np.array([255, 255, 255])
lowerBound = np.array([25,25,25])
mask = cv2.inRange(hsv, lowerBound, white)
res = cv2.bitwise_and(img, img, mask=mask)

# %%
plt.imshow(img)
plt.show()

# %%
plt.imshow(res)
plt.show()

# %%
ret,thresh_img = cv2.threshold(res,0,255,cv2.THRESH_BINARY)

# %%
plt.imshow(thresh_img)
plt.show()
